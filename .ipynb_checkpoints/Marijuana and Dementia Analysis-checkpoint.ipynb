# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

#Ignore all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#load and preview file
df = pd.read_excel("data.xlsx")
df
# Out:
#         id  age  age1bir             racethn                 educatn  \
# 0    12001   27     23.0  White not Hispanic          Diploma or GED
# 1    12002   21      NaN  Black not Hispanic  No high school diploma
# 2    12003   44     16.0  Black not Hispanic          Diploma or GED
# 3    12004   27     18.0  Black not Hispanic          Diploma or GED
# 4    12005   40     25.0  Black not Hispanic  No high school diploma
# ..     ...  ...      ...                 ...                     ...
# 945  12946   36     17.0  Black not Hispanic          Diploma or GED
# 946  12947   37     18.0  Black not Hispanic  No high school diploma
# 947  12948   40     16.0  Black not Hispanic          Diploma or GED
# 948  12949   35     20.0            Hispanic  No high school diploma
# 949  12950   29     15.0  Black not Hispanic  No high school diploma
#
#            marital  kidshh        poverty  ervisit docvisit  ... births  \
# 0         Divorced       2  Below poverty        3       10  ...      2
# 1    Never married       0  Below poverty        0        2  ...      6
# 2         Divorced       7  Below poverty        1        1  ...      8
# 3          Married       2  Below poverty        1        0  ...      2
# 4    Never married       2  Below poverty        2        1  ...      4
# ..             ...     ...            ...      ...      ...  ...    ...
# 945  Never married       4  Below poverty        0        2  ...      4
# 946  Never married       2  Below poverty        0        4  ...      2
# 947  Never married       2  Below poverty        2        1  ...      3
# 948  Never married       4  Below poverty        0       12  ...      5
# 949  Never married       4  Below poverty        4        6  ...      4
#
#      miscarr  totpregs          drunk        usedpot  usedcrck  \
# 0          0         2          Never          Never     Never
# 1          0         7          Never          Never     Never
# 2          1         9          Never          Never     Never
# 3          2         4          Never  Once or twice     Never
# 4          1         6          Never          Never     Never
# ..       ...       ...            ...            ...       ...
# 945        0         4          Never          Never     Never
# 946        1         4       3+ times       3+ times     Never
# 947        2         5  Once or twice  Once or twice     Never
# 948        0         8  Once or twice          Never     Never
# 949        0         4          Never          Never     Never
#
#                FeltDown PhysicalHlth MentalHlth   MEIS
# 0      None of the time       27.392     39.927  3.835
# 1      Some of the time       40.366     43.756  1.117
# 2      Some of the time       37.136     55.862  0.668
# 3      Some of the time       46.609     51.807  2.441
# 4      Some of the time       32.329     49.068  1.931
# ..                  ...          ...        ...    ...
# 945    None of the time       56.577     60.758  0.716
# 946    Most of the time       59.339     47.969  1.360
# 947    Some of the time       40.758     31.346  0.199
# 948    Most of the time       48.017     23.168  2.527
# 949  Little of the time       53.302     28.190  0.815
#
# [950 rows x 24 columns]

# %% [markdown]
# # Data Understanding

# %%
#description of columns 
#check metadata for more understanding
df.columns
# Out:
# Index(['id', 'age', 'age1bir', 'racethn', 'educatn', 'marital', 'kidshh',
#        'poverty', 'ervisit', 'docvisit', 'smoker', 'Height', 'Weight', 'bmi',
#        'births', 'miscarr', 'totpregs', 'drunk', 'usedpot', 'usedcrck',
#        'FeltDown', 'PhysicalHlth', 'MentalHlth', 'MEIS'],
#       dtype='object')

# %%
#check general information/ data description
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            950 non-null    int64
#  1   age           950 non-null    int64
#  2   age1bir       883 non-null    float64
#  3   racethn       950 non-null    object
#  4   educatn       950 non-null    object
#  5   marital       950 non-null    object
#  6   kidshh        950 non-null    int64
#  7   poverty       950 non-null    object
#  8   ervisit       950 non-null    int64
#  9   docvisit      950 non-null    object
#  10  smoker        950 non-null    object
#  11  Height        950 non-null    int64
#  12  Weight        950 non-null    int64
#  13  bmi           948 non-null    float64
#  14  births        950 non-null    int64
#  15  miscarr       950 non-null    int64
#  16  totpregs      950 non-null    int64
#  17  drunk         950 non-null    object
#  18  usedpot       950 non-null    object
#  19  usedcrck      950 non-null    object
#  20  FeltDown      950 non-null    object
#  21  PhysicalHlth  950 non-null    float64
#  22  MentalHlth    950 non-null    float64
#  23  MEIS          950 non-null    float64
# dtypes: float64(5), int64(9), object(10)
# memory usage: 178.2+ KB

# %% [markdown]
# The summary informs data is composed of 950 entries, 24 columns, and the following datatypes float64(5), int64(9), object(10).
# The data occupies a memory of 178.2+kb.
# We also have values missing in bmi and age1bir columns.

# %%
#check duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning

# %%
# delete id column not necessary 
df.drop(columns = "id", inplace= True)

# %%
# filling missing values in bmi and age1birth columns
df[["bmi","age1bir"]].isna().sum()
# Out:
# bmi         2
# age1bir    67
# dtype: int64

# %%
#Statistical summary of the two columns 
#to aid in filling missing values
df[["bmi","age1bir"]].describe().T
# Out:
#          count       mean       std    min    25%    50%    75%    max
# bmi      948.0  29.167131  7.363334  14.54  23.97  27.97  32.64  60.13
# age1bir  883.0  19.557191  3.703872  11.00  17.00  19.00  21.00  42.00

# %%
#visualize distribution of bmi and age1bir
#plot subplots
fig, axs =plt.subplots(1,2, figsize =(15,6))

# Plot histogram for 'age1bir' in the first subplot (axs[0])
axs[0].hist(df["age1bir"], bins=20, color='blue', alpha=0.7)
axs[0].set_title('Histogram of age1bir')
axs[0].set_xlabel('Age at First Birth')
axs[0].set_ylabel('Frequency')

# Plot histogram for 'bmi' in the second subplot (axs[1])
axs[1].hist(df["bmi"], bins=20, color='green', alpha=0.7)
axs[1].set_title('Histogram of BMI')
axs[1].set_xlabel('BMI')
axs[1].set_ylabel('Frequency')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# The distibution of both graphs is a skew on the right.
# Replace missing values with median because If your data is skewed, using the median to fill missing values can help maintain the typical central tendency without being heavily influenced by extreme values in the tail.

# %%
#fill missing values 
df["bmi"].fillna(df["bmi"].median(), inplace =True )
df["age1bir"].fillna(df["age1bir"].median(),inplace= True)

# %%
print("Missing value for bmi:", df["bmi"].isna().sum(),"\nMissing value for age1bir:", df["age1bir"].isna().sum())
print("Dataset is ready for analysis and modelling")
# Out:
# Missing value for bmi: 0
# Missing value for age1bir: 0
# Dataset is ready for analysis and modelling

# %% [markdown]
# # Data Analysis(Exploration)

# %%
#preview first 4 observations of the dataset
df.head(4)
# Out:
#    age  age1bir             racethn                 educatn        marital  \
# 0   27     23.0  White not Hispanic          Diploma or GED       Divorced
# 1   21     19.0  Black not Hispanic  No high school diploma  Never married
# 2   44     16.0  Black not Hispanic          Diploma or GED       Divorced
# 3   27     18.0  Black not Hispanic          Diploma or GED        Married
#
#    kidshh        poverty  ervisit docvisit smoker  ...  births  miscarr  \
# 0       2  Below poverty        3       10     No  ...       2        0
# 1       0  Below poverty        0        2    Yes  ...       6        0
# 2       7  Below poverty        1        1     No  ...       8        1
# 3       2  Below poverty        1        0     No  ...       2        2
#
#    totpregs  drunk        usedpot  usedcrck          FeltDown PhysicalHlth  \
# 0         2  Never          Never     Never  None of the time       27.392
# 1         7  Never          Never     Never  Some of the time       40.366
# 2         9  Never          Never     Never  Some of the time       37.136
# 3         4  Never  Once or twice     Never  Some of the time       46.609
#
#   MentalHlth   MEIS
# 0     39.927  3.835
# 1     43.756  1.117
# 2     55.862  0.668
# 3     51.807  2.441
#
# [4 rows x 23 columns]

# %% [markdown]
# #### 1. Understanding Age distribution
# important to understand the composition of the population represented by the sample

# %%
#unique ages of samples
print("Ages: " , df["age"].unique())

#group observations into groups based on their age 
Agebelow20 = []
Agebelow30 = []
Ageabove30 = []

def grouping_byAge(age):
    if age < 20:
        Agebelow20.append(age)
    elif age >20 and age <30:
        Agebelow30.append(age)
    else:
        Ageabove30.append(age)
# Apply the grouping function to each age in the DataFrame
df['age'].apply(grouping_byAge)

#Access the grouped ages by count
count_below20 = len(Agebelow20)
count_between20and30 = len(Agebelow30)
count_above30 = len(Ageabove30)


#View the counts of age groups
print("Count of ages below 20:", count_below20)
print("Count of ages between 20 and 30:", count_between20and30)
print("Count of ages above 30:", count_above30)
# Out:
# Ages:  [27 21 44 40 36 28 33 38 25 29 24 49 48 26 45 47 23 32 22 46 43 42 41 39
#  37 35 34 31 30 19]
# Count of ages below 20: 1
# Count of ages between 20 and 30: 146
# Count of ages above 30: 803

# %%
#visualize the age groups using a pie chart
#categorize data
grouped_ages = [count_below20,count_between20and30,count_above30]

#colours for the categorized data
colors = ["blue","grey","lightgreen"]

#create labels for the categories
labeling = ["age<20","20<age<30","age>30"]

# Plotting the pie chart
plt.figure(figsize=(8, 6))  # Adjust size if needed
plt.pie(grouped_ages, labels=labeling, colors=colors, autopct='%1.1f%%', startangle=150)
plt.title('Age Distribution of the Sampled Population')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Inferences:
# Of the sampled population, it appears that the a majority of the population is above 30 years of age. Only 0.1% represented those below 19 years of age. Individuals above 30 years participated more in the study giving an impression that demographic is made of individuals above 30 years of age and those between 20 and 30. The distribution informed further analysis and modelling focusing on only two groups,those between 20 and 30, and those above 30 years since they formed a larger portion of the population.

# %% [markdown]
# #### 2. Understanding other Demographics of the sampled population: Focus on the two major Age groups

# %%
#Select features that compose a demographic traits
demographics_df = df[['age', 'age1bir', 'racethn', 'educatn', 'marital', 'kidshh',
                    'poverty', 'ervisit', 'docvisit', 'smoker', 'bmi','births', 
                    'miscarr', 'totpregs', 'drunk','FeltDown', 'PhysicalHlth', 'MentalHlth']]

#Group data into two main age groups
#group age between 20 and 30
age_20_30 = demographics_df[(demographics_df['age'] >= 20) & (demographics_df['age'] <= 30)]

# group age above 30
age_above30 = demographics_df[(demographics_df["age"])>=30]

# %% [markdown]
# #### 2.1 Demographics Distribution Analysis of Age between 20 and 30

# %%
#Number of samples aged between 20 and 30
age_20_30.shape
# Out:
# (166, 18)

# %%
#columns in this age group
age_20_30.columns
# Out:
# Index(['age', 'age1bir', 'racethn', 'educatn', 'marital', 'kidshh', 'poverty',
#        'ervisit', 'docvisit', 'smoker', 'bmi', 'births', 'miscarr', 'totpregs',
#        'drunk', 'FeltDown', 'PhysicalHlth', 'MentalHlth'],
#       dtype='object')

# %%
def value_counts_plot(data, columns):
    """
    This functions generates the value counts for every column in the data
    The generated value counts are then plotted for demographic visualization
    
    Parameters:
    - data: respective DataFrame
    - column: desired columns in the data
    
    Functions uses a bar plot.
    """
    num_cols = len(columns)
    num_rows = math.ceil(num_cols / 2)  # Calculate number of rows needed
    
    plt.figure(figsize=(16, 4 * num_rows))  # Adjust figure size based on number of rows
    
    for i, col in enumerate(columns, start=1):
        plt.subplot(num_rows, 4, i)  # Adjust subplot layout based on number of columns
        value_counts = df[col].value_counts()
        value_counts.plot(kind='bar', color='lightblue', alpha=0.8)
        plt.title(f'Value Counts for {col}')
        plt.xlabel('Unique Values(Categories')
        plt.ylabel('Value Counts')
        plt.xticks(rotation=45)  # Rotate x-axis labels if needed
        plt.tight_layout()

# %%
# Select Columns to use
columns = ['age', 'age1bir', 'racethn', 'educatn', 'marital', 'kidshh', 'poverty',
           'ervisit', 'docvisit', 'smoker', 'births', 'miscarr', 'totpregs',
           'drunk', 'FeltDown']

# Execute function on desired data
value_counts_plot(age_20_30, columns)

# Plot graphs
plt.show()

# %% [markdown]
# #### Summarized Demographic Understanding
# - About 166 individuals sampled were aged between 20 and 30 years
# - Of the sampled population aged between 20 and 30, most of the individuals are aged 25, 26, 29, 30, and 27 years in that order
# - Most of the individuals have their first birth at 19, 17, 16, and 18 years in that order
# - Most are Black not Hispanic in race and ethnicity with a small section being White not Hispanic
# - In terms of education, a majority possess a Diploma or GED and the second majority had no High School diploma. Only a small section has BA degree
# - About marital status, most are never married. Those are married are equally divorced as seen in the graph
# - Also, most have little number of children. In their respective order, most had 2, 3,1,4,and 5 kids in the order
# - The analysis shows that a majority of individuals live below poverty
# - The first five highest number of emergency visits among this sample are no visit, 1,2,3, and 4 respectively
# - On the other hand, number of doctor visits are 2,4,3,1, no visit, and 6 with the highest visit being and the least 6 for the first five highest visits
# - In regards to smoking, a majority of this sample are not smokers
# - About drinking, most have drunk, a significant portion has at most drunk twice, with a smaller section having drunk at least thrice
# - Out of those who have been pregnant, the case of miscarriage in decreasing order is none, 1,2 and 3 respectively
# - The total number of pregnancy in decreasing order is 3,2,4,5,1, and 1 for the first six highest total pregnancies.
# - In regards to falling down in a decreasing order, none felt, an equally number felt little of the time, a significant also felt down some of the time, and an insignificant number felt down most of the time.

# %%
age_20_30.head(2)
# Out:
#    age  age1bir             racethn                 educatn        marital  \
# 0   27     23.0  White not Hispanic          Diploma or GED       Divorced
# 1   21     19.0  Black not Hispanic  No high school diploma  Never married
#
#    kidshh        poverty  ervisit docvisit smoker    bmi  births  miscarr  \
# 0       2  Below poverty        3       10     No  18.65       2        0
# 1       0  Below poverty        0        2    Yes  22.33       6        0
#
#    totpregs  drunk          FeltDown  PhysicalHlth  MentalHlth
# 0         2  Never  None of the time        27.392      39.927
# 1         7  Never  Some of the time        40.366      43.756

# %%
#### Understanding Correlation of Numerical columns

# %%
def segregate_columns_by_dtype(df):
    """
    Segregates columns of a DataFrame based on their dtype.

    Args:
    - df (pd.DataFrame): Input DataFrame.

    Returns:
    - numerical_df (pd.DataFrame): DataFrame containing numerical columns.
    - categorical_df (pd.DataFrame): DataFrame containing categorical columns.
    """
    numerical_df = pd.DataFrame()
    categorical_df = pd.DataFrame()

    for column in df.columns:
        if np.issubdtype(df[column].dtype, np.number):  # Check if column is numeric
            numerical_df[column] = df[column]
        else:
            categorical_df[column] = df[column]

    return numerical_df, categorical_df

# %%
segregate_columns_by_dtype(age_20_30)
# Out:
# (     age  age1bir  kidshh  ervisit    bmi  births  miscarr  totpregs  \
#  0     27     23.0       2        3  18.65       2        0         2
#  1     21     19.0       0        0  22.33       6        0         7
#  3     27     18.0       2        1  34.98       2        2         4
#  6     28     16.0       5        2  23.32       5        0         6
#  11    25     16.0       5        0  20.42       5        1         6
#  ..   ...      ...     ...      ...    ...     ...      ...       ...
#  820   28     19.0       5        6  21.63       5        0         5
#  839   24     16.0       4        0  43.11       4        0         4
#  842   27     17.0       3        3  21.32       3        0         3
#  894   27     19.0       0        6  24.82       1        2         4
#  949   29     15.0       4        4  57.61       4        0         4
#
#       PhysicalHlth  MentalHlth
#  0          27.392      39.927
#  1          40.366      43.756
#  3          46.609      51.807
#  6          52.168      57.379
#  11         54.741      53.745
#  ..            ...         ...
#  820        55.915      51.602
#  839        43.905      38.769
#  842        36.744      68.419
#  894        47.138      21.005
#  949        53.302      28.190
#
#  [166 rows x 10 columns],
#                  racethn                 educatn        marital        poverty  \
#  0    White not Hispanic          Diploma or GED       Divorced  Below poverty
#  1    Black not Hispanic  No high school diploma  Never married  Below poverty
#  3    Black not Hispanic          Diploma or GED        Married  Below poverty
#  6    Black not Hispanic          Diploma or GED  Never married  Below poverty
#  11   Black not Hispanic  No high school diploma  Never married  Below poverty
#  ..                  ...                     ...            ...            ...
#  820  White not Hispanic  No high school diploma  Never married  Below poverty
#  839  Black not Hispanic          Diploma or GED  Never married  Below poverty
#  842  Black not Hispanic  No high school diploma  Never married  Below poverty
#  894  Black not Hispanic          Diploma or GED  Never married  Below poverty
#  949  Black not Hispanic  No high school diploma  Never married  Below poverty
#
#      docvisit smoker          drunk            FeltDown
#  0         10     No          Never    None of the time
#  1          2    Yes          Never    Some of the time
#  3          0     No          Never    Some of the time
#  6          6    Yes       3+ times    None of the time
#  11         0     No          Never  Little of the time
#  ..       ...    ...            ...                 ...
#  820       12     No          Never  Little of the time
#  839       30     No          Never    Some of the time
#  842        4    Yes  Once or twice    None of the time
#  894        2    Yes          Never    Most of the time
#  949        6     No          Never  Little of the time
#
#  [166 rows x 8 columns])

# %%
# Initialize global variables
numerical_df = pd.DataFrame()
categorical_df = pd.DataFrame()

def segregate_columns_by_dtype(df):
    """
    Segregates columns of a DataFrame based on their dtype.

    Args:
    - df (pd.DataFrame): Input DataFrame.

    """
    global numerical_df, categorical_df  # Access global variables

    for column in df.columns:
        if np.issubdtype(df[column].dtype, np.number):  # Check if column is numeric
            numerical_df[column] = df[column]
        else:
            categorical_df[column] = df[column]

# Call the function to segregate columns
segregate_columns_by_dtype(df)

# %%
segregate_columns_by_dtype(age_20_30)

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           166 non-null    float64
#  1   age1bir       166 non-null    float64
#  2   kidshh        166 non-null    float64
#  3   ervisit       166 non-null    float64
#  4   Height        950 non-null    int64
#  5   Weight        950 non-null    int64
#  6   bmi           166 non-null    float64
#  7   births        166 non-null    float64
#  8   miscarr       166 non-null    float64
#  9   totpregs      166 non-null    float64
#  10  PhysicalHlth  166 non-null    float64
#  11  MentalHlth    166 non-null    float64
#  12  MEIS          950 non-null    float64
# dtypes: float64(11), int64(2)
# memory usage: 96.6 KB

# %%
numerical_df_filled = numerical_df.fillna(0)
numerical_df_filled.isna().sum()
# Out:
# age             0
# age1bir         0
# kidshh          0
# ervisit         0
# Height          0
# Weight          0
# bmi             0
# births          0
# miscarr         0
# totpregs        0
# PhysicalHlth    0
# MentalHlth      0
# MEIS            0
# dtype: int64

# %%
numerical_df_filled.corr()
# Out:
#                    age   age1bir    kidshh   ervisit    Height    Weight  \
# age           1.000000  0.988644  0.858307  0.503734  0.010020 -0.006423
# age1bir       0.988644  1.000000  0.818917  0.498097  0.018072 -0.016699
# kidshh        0.858307  0.818917  1.000000  0.434816 -0.019856 -0.006803
# ervisit       0.503734  0.498097  0.434816  1.000000 -0.003470 -0.026867
# Height        0.010020  0.018072 -0.019856 -0.003470  1.000000  0.260834
# Weight       -0.006423 -0.016699 -0.006803 -0.026867  0.260834  1.000000
# bmi           0.966955  0.952900  0.831017  0.474231  0.012383  0.078930
# births        0.879577  0.851107  0.941645  0.429025 -0.029576 -0.025764
# miscarr       0.493125  0.470457  0.384799  0.361184  0.062411  0.044720
# totpregs      0.886765  0.859782  0.884770  0.523420 -0.000606  0.007210
# PhysicalHlth  0.972174  0.971344  0.822123  0.465585 -0.001513 -0.031207
# MentalHlth    0.958802  0.962531  0.811850  0.427066  0.012674 -0.012892
# MEIS          0.014675  0.015018  0.027949  0.043193 -0.022260 -0.085804
#
#                    bmi    births   miscarr  totpregs  PhysicalHlth  \
# age           0.966955  0.879577  0.493125  0.886765      0.972174
# age1bir       0.952900  0.851107  0.470457  0.859782      0.971344
# kidshh        0.831017  0.941645  0.384799  0.884770      0.822123
# ervisit       0.474231  0.429025  0.361184  0.523420      0.465585
# Height        0.012383 -0.029576  0.062411 -0.000606     -0.001513
# Weight        0.078930 -0.025764  0.044720  0.007210     -0.031207
# bmi           1.000000  0.840484  0.491392  0.863819      0.940013
# births        0.840484  1.000000  0.356263  0.923303      0.844784
# miscarr       0.491392  0.356263  1.000000  0.584937      0.469169
# totpregs      0.863819  0.923303  0.584937  1.000000      0.847378
# PhysicalHlth  0.940013  0.844784  0.469169  0.847378      1.000000
# MentalHlth    0.930091  0.829236  0.454791  0.830939      0.945720
# MEIS          0.007047  0.022241  0.011689  0.016643      0.020745
#
#               MentalHlth      MEIS
# age             0.958802  0.014675
# age1bir         0.962531  0.015018
# kidshh          0.811850  0.027949
# ervisit         0.427066  0.043193
# Height          0.012674 -0.022260
# Weight         -0.012892 -0.085804
# bmi             0.930091  0.007047
# births          0.829236  0.022241
# miscarr         0.454791  0.011689
# totpregs        0.830939  0.016643
# PhysicalHlth    0.945720  0.020745
# MentalHlth      1.000000  0.019726
# MEIS            0.019726  1.000000

# %% [markdown]
# age and age1bir: These two variables have a very high correlation coefficient of approximately 0.99, indicating they are almost perfectly positively correlated. This suggests that as "age" increases, "age1bir" also tends to increase nearly in lockstep.
#
# PhysicalHlth and MentalHlth: These variables also show high positive correlation (approximately 0.96), indicating that better physical health tends to be associated with better mental health, and vice versa.
#
# bmi and age: The correlation coefficient is 0.97, indicating a strong positive correlation between BMI and age. This suggests that BMI tends to increase with age.
#
# Weight and Height: The correlation coefficient is relatively low (0.26), indicating a weak positive correlation between weight and height. This suggests that taller individuals tend to have slightly higher weights, but the relationship is not very strong.
#
# MEIS and other variables: The MEIS variable shows very low correlations (close to zero) with other variables in the dataset. This suggests that MEIS may not have significant linear relationships with the other variables examined here.
#
#     Strength of Correlations: Generally, correlations above 0.7 or below -0.7 are considered strong, while correlations between 0.3 to 0.7 (or -0.3 to -0.7) are moderate, and correlations below 0.3 (or above -0.3) are considered weak.
#
#     Direction of Correlation: A positive correlation means that as one variable increases, the other tends to increase as well. A negative correlation means that as one variable increases, the other tends to decrease.
#
#     Cautions: While correlation coefficients provide insights into relationships between variables, they do not indicate causation. Correlation does not imply causation, meaning that just because two variables are correlated does not mean that changes in one variable cause changes in the other.
#
# In summary, the correlation matrix helps to identify which variables are strongly related to each other and the direction of their relationship. It's essential to interpret these correlations in the context of your specific dataset and research questions.

# %%
# Compute correlation between column1 and column2
corr = df[column1].corr(df[column2])

print(f"Correlation between '{column1}' and '{column2}': {corr}")

# %% [markdown]
# #### 2.2 Demographic Analysis of Sample age above 30 years

# %%
#Number of individuals aged above 30 years 
age_above30.shape
# Out:
# (803, 18)

# %%
# Execute function on desired data
value_counts_plot(age_above30, columns)

# Plot graphs
plt.show()

# %% [markdown]
# ###### Summarized Demographic Understanding
